# %% [markdown]
# # AlgorithmicToolBox
# ### Certificado Coursera

# %% [markdown]
# ![Algorithmic Toolbox.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Link del Certificado

# %% [markdown]
# https://www.coursera.org/account/accomplishments/certificate/G6D2WQX28ZB9
